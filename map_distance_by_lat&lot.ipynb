# %%
import pandas as pd 
from math import radians, sin, cos, acos

df= pd.read_csv(r'D:\final project\Dataset\complete_orders.csv')
 
df.head()
# Out:
#    Unnamed: 0                          order_id  \
# 0           2  e481f51cbdc54678b7cc49136f2d6af7
# 1           3  128e10d95713541c87cd1a2e48201934
# 2           4  0e7e841ddf8f8f2de2bad69267ecfbcf
# 3           5  bfc39df4f36c3693ff3b63fcbea9e90a
# 4           6  53cdb2fc8bc7dce0b6741e2150273451
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  9ef432eb6251297304e76186b10a928d    delivered               2017-02-10
# 1  a20e8105f23924cd00833fd87daa0831    delivered               2017-08-15
# 2  26c7ac168e1433912a51b924fbd34d34    delivered               2017-02-08
# 3  53904ddbea91e1e92b2b3f1d09a7af86    delivered               2017-10-23
# 4  b0830fb4747a6c6d20dea0b8c802d7ef    delivered               2018-07-24
#
#   order_approved_at order_delivered_carrier_date  \
# 0        2017-02-10                   2017-04-10
# 1        2017-08-15                   2017-08-17
# 2        2017-02-08                   2017-04-08
# ...

# %%
Location_1_lat= df['geolocation_lat_customer']
Location_1_lot= df['geolocation_lng_customer']
Location_2_lat= df['geolocation_lat_seller']
Location_2_lot= df['geolocation_lng_seller']
print("Input coordinates of two points:")
mlat = radians(float(input("Location 1 latitude: ")))
mlon = radians(float(input("Location 1 longitude:")))
plat = radians(float(input("Location 2 latitude: ")))
plon = radians(float(input("Location 2 longitude: ")))
 
dist = 6371.01 * acos(sin(mlat)*sin(plat) + cos(mlat)*cos(plat)*cos(mlon - plon))
print("The distance is %.2fkm." % dist)
# Out:
# Input coordinates of two points:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 print("Input coordinates of two points:")
#       2 mlat = radians(float(input("Location 1 latitude: df['geolocation_lat_customer'] ")))
# ----> 3 mlon = radians(float(input("Location 2 longitude: df['geolocation_lng_seller']")))
#       4 plat = radians(float(input("Location 1 latitude: df['geolocation_lat_seller']")))
#       5 plon = radians(float(input("Location 2 longitude: df['geolocation_lng_customer']")))
#
# File c:\Users\User\Desktop\JDE 11 python file\myEnv\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
# ...

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv(r'D:\final project\Dataset\complete_orders.csv')

def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees).
    """
    # Convert decimal degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Haversine formula
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    return 6371.01 * c  # Radius of Earth in kilometers

def calculate_distances(df):
    """
    Calculate distances between customers and sellers in the DataFrame.
    Adds a new column 'distance_km' with calculated distances.
    """
    df['distance_km'] = haversine(df['geolocation_lat_customer'], 
                                   df['geolocation_lng_customer'], 
                                   df['geolocation_lat_seller'], 
                                   df['geolocation_lng_seller'])
    return df

# Calculate distances and add to DataFrame
df_with_distances = calculate_distances(df)

# Display the first few rows of the updated DataFrame with distances
print(df_with_distances[['geolocation_lat_customer', 'geolocation_lng_customer', 
                         'geolocation_lat_seller', 'geolocation_lng_seller', 
                         'distance_km']].head())

# If you want to save this updated DataFrame to a new CSV file
df_with_distances.to_csv(r'D:\final project\Dataset\complete_orders_with_distances.csv', index=False)
# Out:
#    geolocation_lat_customer  geolocation_lng_customer  geolocation_lat_seller  \
# 0                -23.583452                -46.586284              -23.675542
# 1                -23.564977                -46.536043              -23.675542
# 2                -23.532175                -46.626106              -23.675542
# 3                -27.553442                -48.500027              -23.675542
# 4                -12.124719                -45.011148              -19.813375
#
#    geolocation_lng_seller  distance_km
# 0              -46.442547    17.867989
# 1              -46.442547    15.552497
# 2              -46.442547    24.575274
# 3              -46.442547   477.982142
# 4              -43.984022   861.950338

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv(r'D:\final project\Dataset\complete_orders.csv')

# Create a DataFrame for states with their latitudes and longitudes
state_data = {
    'state': ['Acre', 'Alagoas', 'Amazonas', 'Amapá', 'Bahia', 
              'Ceará', 'Distrito Federal', 'Espírito Santo', 
              'Goiás', 'Maranhão', 'Minas Gerais', 'Mato Grosso do Sul', 
              'Mato Grosso', 'Pará', 'Paraíba', 'Pernambuco', 
              'Piauí', 'Paraná', 'Rio de Janeiro', 
              'Rio Grande do Norte', 'Rondônia', 'Roraima', 
              'Rio Grande do Sul', 'Santa Catarina', 
              'Sergipe', 'São Paulo', 'Tocantins'],
    'state_lat': [32.9325, -9.648139, -3.117034, 0.035574, -11.409874, 
                  -3.731862, -15.793889, -2.950000, -16.665136, 
                  -2.533333, -19.912998, -22.692245, -16.350000, 
                  -1.455833, -3.9536867, -8.472372, -16.967, 
                  -25.441105, -22.908333, -5.402580, 
                  -10.943145, 2.135138, -29.8425284, 
                  -27.0628367, -10.6743911, -22.121265, -10.183],
    'state_lon': [35.08194444, -35.717239, -60.02578, -51.070534,
                  -41.280857, -38.526669, -47.882778, -69.117,
                  -49.286041, -43.116669, -43.940933, -53.433807,
                  -56.666668, -48.503887, -55.2949115,
                  -37.946777, -41.850,
                  -49.276855, -43.196388,
                  -36.954105, -62.8277863,
                  -61.3631922, -53.7680577,
                  -51.114965, -37.3773519,
                  -51.3834, -48.333]
}


# Assuming 'seller_state' and 'customer_state' are columns with state names
# Map seller_state and customer_state to their lat/lon values
df[['seller_state_lat']] = df['seller_state'].map(state_data)
df[['seller_state_lon']] = df['seller_state'].map(state_data)
df[['customers_state_lat']] = df['customer_state'].map(state_data)
df[[ 'customers_state_lon']] = df['customer_state'].map(state_data)
# Optionally save this updated DataFrame to a new CSV file
df.to_csv(r'D:\final project\Dataset\complete_orders_with_states_and_distances.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 39
#       8 state_data = {
#       9     'state': ['Acre', 'Alagoas', 'Amazonas', 'Amapá', 'Bahia',
#      10               'Ceará', 'Distrito Federal', 'Espírito Santo',
#    (...)
#      33                   -51.3834, -48.333]
#      34 }
#      37 # Assuming 'seller_state' and 'customer_state' are columns with state names
#      38 # Map seller_state and customer_state to their lat/lon values
# ---> 39 df[['seller_state_lat']] = df['seller_state'].map(state_data)
#      40 df[['seller_state_lon']] = df['seller_state'].map(state_data)
#      41 df[['customers_state_lat']] = df['customer_state'].map(state_data)
#
# File c:\Users\User\Desktop\JDE 11 python file\myEnv\Lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
# ...

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv(r'D:\final project\Dataset\complete_orders.csv')

# Create a DataFrame for states with their latitudes and longitudes
state_data = {
    'state': ["AC","AL","AM","AP","BA","CE","DF",
              "ES","GO","MA","MG","MS","MT","PA",
              "PB","PE","PI","PR","RJ","RN","RO"
              ,"RR","RS","SC","SE","SP","TO"],
    'state_lat': [32.9325, -9.648139, -3.117034, 0.035574, -11.409874, 
                  -3.731862, -15.793889, -2.950000, -16.665136, 
                  -2.533333, -19.912998, -22.692245, -16.350000, 
                  -1.455833, -3.9536867, -8.472372, -16.967, 
                  -25.441105, -22.908333, -5.402580, 
                  -10.943145, 2.135138, -29.8425284, 
                  -27.0628367, -10.6743911, -22.121265, -10.183],
    'state_lon': [35.08194444, -35.717239, -60.02578, -51.070534,
                  -41.280857, -38.526669, -47.882778, -69.117,
                  -49.286041, -43.116669, -43.940933, -53.433807,
                  -56.666668, -48.503887, -55.2949115,
                  -37.946777, -41.850,
                  -49.276855, -43.196388,
                  -36.954105, -62.8277863,
                  -61.3631922, -53.7680577,
                  -51.114965, -37.3773519,
                  -51.3834, -48.333]
}

# Restructure state_data for mapping
state_lat_map = dict(zip(state_data['state'], state_data['state_lat']))
state_lon_map = dict(zip(state_data['state'], state_data['state_lon']))


# Map seller_state and customer_state to their lat/lon values
df['seller_state_lat'] = df['seller_state'].map(state_lat_map)
df['seller_state_lon'] = df['seller_state'].map(state_lon_map)
df['customers_state_lat'] = df['customer_state'].map(state_lat_map)
df['customers_state_lon'] = df['customer_state'].map(state_lon_map)

# Optionally save this updated DataFrame to a new CSV file
df.to_csv(r'D:\final project\Dataset\complete_orders_with_states_and_distances.csv', index=False)

# %%
def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees).
    """
    # Convert decimal degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Haversine formula
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    return 6371.01 * c  # Radius of Earth in kilometers

def calculate_distances(df):
    """
    Calculate distances between customers and sellers in the DataFrame.
    Adds a new column 'distance_km' with calculated distances.
    """
    df['distance_km'] = haversine(df['customers_state_lat'], 
                                   df['customers_state_lon'], 
                                   df['seller_state_lat'], 
                                   df['seller_state_lon'])
    return df

# Calculate distances and add to DataFrame
df_with_distances = calculate_distances(df)



# If you want to save this updated DataFrame to a new CSV file
df_with_distances.to_csv(r'D:\final project\Dataset\complete_orders_with_distances_states.csv', index=False)
